# %% [markdown]
# # **Project Name**    -   AMAZON PRIME MOVIES AND SHOWS DATA ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member  -**  - SIVASUBRAMANIAN S

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The dataset consists of two files, credits.csv and titles.csv, which provide valuable insights into movies and TV shows. The credits dataset contains 124,235 records with details about actors, directors, and other crew members, including their roles and character names. The titles dataset, with 9,871 entries, includes information on movies and TV shows, such as their release year, runtime, genres, production countries, IMDb and TMDb ratings, and popularity scores. However, some data quality issues exist, including missing values in character names, age certification, IMDb scores, and descriptions. Additionally, genres and production countries are stored as strings rather than lists, requiring preprocessing for accurate analysis.
# \
# For Exploratory Data Analysis (EDA), several key questions can be explored. First, we can analyze the distribution of movies and TV shows, the most common genres, and production trends over the years. Next, examining IMDb and TMDb ratings can help identify the most popular and highly-rated titles, while also exploring the correlation between IMDb votes and scores. Additionally, a deep dive into cast and crew data can reveal the most credited actors and directors and uncover frequent collaborations in the industry. Lastly, studying runtime distributions and season counts can provide insights into the length and structure of movies and TV series. By addressing these aspects, we can gain a comprehensive understanding of the dataset and extract meaningful trends in the entertainment industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/sivasubramanian2004/Amazon-prime-movies-and-shows-analysis-EDA-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Amazon Prime Video is one of the leading streaming platforms, offering a vast collection of movies and TV shows across various genres and languages. Understanding the patterns and trends in its content library is crucial for both content creators and platform strategists. This **Exploratory Data Analysis (EDA)** project aims to uncover key insights about **the distribution of content, genre popularity, ratings, and trends over time**.
#
# The primary objectives of this analysis include:
# - Examining the **distribution of movies vs. TV shows** on Amazon Prime.
# - Identifying the **most common genres and production countries** to understand content diversity.
# - Analyzing the **trend of content production over the years**, highlighting growth patterns.
# - Investigating the **IMDb and TMDb ratings**, including their correlation with popularity and votes.
# - Exploring the **runtime of movies and number of seasons for TV shows** to find content length trends.
# - Evaluating the **cast and crew data** to determine the most frequently credited actors and directors.
#
# By addressing these aspects, this EDA will provide valuable insights into **content trends, audience preferences, and rating distributions** on Amazon Prime Video, helping stakeholders make data-driven decisions for content strategy and recommendations..**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
#  Analyze Amazon Prime's content data to uncover trends in ratings, genres, directors, and regional content production, enabling data-driven decisions to enhance user engagement and content strategy

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
credits_df = pd.read_csv(r'D:\labmentix intern\Amazon Prime EDA\credits.csv')
titles_df = pd.read_csv(r'D:\labmentix intern\Amazon Prime EDA\titles.csv')

# %%
merged_df = credits_df.merge(titles_df, on="id", how="inner")

# %% [markdown]
# ### Dataset First View

# %%
merged_df.head(10)
# Out:
#    person_id       id                 name           character   role  \
# 0      59401  ts20945           Joe Besser                 Joe  ACTOR
# 1      31460  ts20945           Moe Howard                 Moe  ACTOR
# 2      31461  ts20945           Larry Fine               Larry  ACTOR
# 3      21174  tm19248        Buster Keaton         Johnny Gray  ACTOR
# 4      28713  tm19248          Marion Mack       Annabelle Lee  ACTOR
# 5      28714  tm19248        Glen Cavender    Captain Anderson  ACTOR
# 6      28715  tm19248           Jim Farley    General Thatcher  ACTOR
# 7      27348  tm19248      Frederick Vroom  A Southern General  ACTOR
# 8      28716  tm19248  Charles Henry Smith  Annabelle's Father  ACTOR
# 9      28718  tm19248           Joe Keaton       Union General  ACTOR
#
#                title   type  \
# 0  The Three Stooges   SHOW
# 1  The Three Stooges   SHOW
# 2  The Three Stooges   SHOW
# 3        The General  MOVIE
# 4        The General  MOVIE
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
print('Number of Rows:',merged_df.shape[0])
print('Number of Columns:',merged_df.shape[1])
# Out:
# Number of Rows: 124347
# Number of Columns: 19

# %% [markdown]
# ### Dataset Information

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124347 non-null  int64
#  1   id                    124347 non-null  object
#  2   name                  124347 non-null  object
#  3   character             108040 non-null  object
#  4   role                  124347 non-null  object
#  5   title                 124347 non-null  object
#  6   type                  124347 non-null  object
#  7   description           124256 non-null  object
#  8   release_year          124347 non-null  int64
#  9   age_certification     56707 non-null   object
#  10  runtime               124347 non-null  int64
#  11  genres                124347 non-null  object
#  12  production_countries  124347 non-null  object
#  13  seasons               8153 non-null    float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
print("Duplicate value count:",merged_df.duplicated().sum())
# Out:
# Duplicate value count: 168

# %%
#removing the Duplicate values row 
print(merged_df.drop_duplicates(inplace = True))
# Out:
# None

# %% [markdown]
# #### Missing Values/Null Values

# %%
missing_values=merged_df.isnull().sum()
print(missing_values)
# Out:
# person_id                    0
# id                           0
# name                         0
# character                16277
# role                         0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67472
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116026
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10169
# dtype: int64

# %%
# To count the number of rows containing atleast one null values
print("number of rows that contains null values: ",merged_df.isnull().any(axis=1).sum())
# Out:
# number of rows that contains null values:  120431

# %%
missing_values = missing_values[missing_values > 0]  # Only show columns with missing values

plt.figure(figsize=(10, 5))
missing_values.plot(kind="bar", color="yellow")
plt.xlabel("Columns")
plt.ylabel("Count of Missing Values")
plt.title("Missing Values Per Column")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After merging the credits.csv and titles.csv datasets and visualizing missing values, we can summarize the key findings:\
#
# 1️⃣ Dataset Structure\
# The merged dataset combines cast & crew details (credits.csv) with movie/show details (titles.csv) using the id column.\
# It contains both TV shows and movies, with attributes like title, genres, release year, runtime, IMDb ratings, and popularity scores.\
# 2️⃣ Missing Values Analysis\
# The heatmap and bar chart showed that several columns have missing values.\
# Columns with missing values:\
# character → Some cast members don’t have assigned character names.\
# age_certification → Many movies/shows lack age ratings.\
# imdb_score, tmdb_score, and imdb_votes → Some titles do not have ratings or votes, possibly due to being less popular.\
# seasons → Mostly missing for movies (since they don’t have seasons).\
# 3️⃣ Duplicate Data\
# Checked for duplicate rows → If duplicates exist, they should be removed using drop_duplicates().
#
# Potential Areas for Analysis\
# Based on these insights, we can explore:\
# ✔ Trends in content production over the years.\
# ✔ Popular genres and their ratings based on IMDb and TMDb scores.\
# ✔ Impact of cast and crew on ratings → Do certain actors or directors contribute to highly rated content?\
# ✔ Differences between movies & TV shows in terms of runtime, ratings, and popularity.\
# ✔ Production countries & content trends → Which countries produce the highest-rated content?

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# Print column names in a readable format
print("Dataset Columns:")
for col in merged_df.columns:
    print("-", col)
# Out:
# Dataset Columns:
# - person_id
# - id
# - name
# - character
# - role
# - title
# - type
# - description
# - release_year
# - age_certification
# - runtime
# - genres
# - production_countries
# - seasons
# - imdb_id
# - imdb_score
# - imdb_votes
# - tmdb_popularity
# - tmdb_score

# %%
# Dataset Describe
# Summary of numerical columns
print(merged_df.describe())
# Out:
#           person_id   release_year        runtime      seasons     imdb_score  \
# count  1.241790e+05  124179.000000  124179.000000  8153.000000  118128.000000
# mean   4.065843e+05    1996.307186      95.577706     2.337790       5.968327
# std    5.617204e+05      27.752141      30.166205     3.130184       1.242262
# min    1.000000e+00    1912.000000       1.000000     1.000000       1.100000
# 25%    3.898850e+04    1983.000000      83.000000     1.000000       5.200000
# 50%    1.339490e+05    2009.000000      93.000000     1.000000       6.100000
# 75%    5.712810e+05    2017.000000     109.000000     2.000000       6.800000
# max    2.371153e+06    2022.000000     540.000000    49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score
# count  1.181040e+05    124164.000000  114010.000000
# mean   2.327575e+04        10.177932       5.991464
# std    8.846004e+04        40.765311       1.321207
# min    5.000000e+00         0.000011       0.800000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset consists of two files, credits.csv and titles.csv, which provide insights into Amazon Prime Video's movie and TV show catalog. The credits.csv file contains information about cast and crew, including person_id (a unique identifier for individuals), id (a unique identifier for movies/shows that links to titles.csv), name (actor or crew member's name), character (the role played by an actor), and role (the person's job, such as ACTOR, DIRECTOR, or WRITER). On the other hand, the titles.csv file provides detailed metadata about the content, including id (which links to credits.csv), title (name of the movie or show), type (MOVIE or SHOW), description (a brief synopsis), release_year (the year it was released), and age_certification (such as G, PG, or R ratings). Additional attributes include runtime (duration in minutes), genres (categories such as Drama, Comedy), production_countries (countries that produced the content), seasons (number of seasons for TV shows), and ratings metrics like imdb_score, imdb_votes, tmdb_popularity, and tmdb_score.
# \
# Since both files share the id column, they can be merged to analyze how cast and crew influence ratings, content trends over time, and the most popular genres and production countries. However, some data quality issues exist, including missing values in columns like character, age_certification, and imdb_score, which need to be handled before further analysis. By exploring trends in ratings, genres, production countries, and cast details, this analysis will provide valuable insights into Amazon Prime Video's content strategy and audience preferences.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Display first 10 unique values for each column
for col in merged_df.columns:
    print(f"Column: {col}")
    print(merged_df[col].unique()[:10])  # Display first 10 unique values
    print("\n")
# Out:
# Column: person_id
# [59401 31460 31461 21174 28713 28714 28715 27348 28716 28718]
#
#
# Column: id
# ['ts20945' 'tm19248' 'tm82253' 'tm83884' 'tm56584' 'tm160494' 'tm87233'
#  'tm19424' 'tm116781' 'tm112005']
#
#
# Column: name
# ['Joe Besser' 'Moe Howard' 'Larry Fine' 'Buster Keaton' 'Marion Mack'
#  'Glen Cavender' 'Jim Farley' 'Frederick Vroom' 'Charles Henry Smith'
#  'Joe Keaton']
#
#
# Column: character
# ['Joe' 'Moe' 'Larry' 'Johnny Gray' 'Annabelle Lee' 'Captain Anderson'
#  'General Thatcher' 'A Southern General' "Annabelle's Father"
#  'Union General']
#
#
# Column: role
# ['ACTOR' 'DIRECTOR']
#
#
# Column: title
# ['The Three Stooges' 'The General' 'The Best Years of Our Lives'
#  'His Girl Friday' 'In a Lonely Place' 'Stagecoach'
#  "It's a Wonderful Life" 'Detour' 'My Man Godfrey' 'Marihuana']
#
#
# Column: type
# ['SHOW' 'MOVIE']
#
#
# Column: description
# ...

# %%
# Display unique value counts for each column
print( "Display unique value counts for each column")
unique_values=merged_df.nunique()
unique_values
# Out:
# Display unique value counts for each column
# person_id               80508
# id                       8861
# name                    79758
# character               71097
# role                        2
# title                    8748
# type                        2
# description              8833
# release_year              110
# age_certification          11
# runtime                   204
# genres                   1965
# production_countries      482
# seasons                    30
# imdb_id                  8267
# imdb_score                 85
# imdb_votes               3623
# tmdb_popularity          5267
# tmdb_score                 88
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# 2️⃣ **Handle Missing Values**
merged_df.fillna({
    "character": "Unknown",
    "age_certification": "Not Rated",
    "imdb_score": merged_df["imdb_score"].median(),
    "tmdb_score": merged_df["tmdb_score"].median(),
    "seasons": 0
}, inplace=True)

# %%
import ast

# Convert 'genres' & 'production_countries' from string to list
merged_df["genres"] = merged_df["genres"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])
merged_df["production_countries"] = merged_df["production_countries"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])

# Convert 'release_year' and 'runtime' to integer (if not already)
merged_df["release_year"] = merged_df["release_year"].astype(int)
merged_df["runtime"] = merged_df["runtime"].astype(int)

# Convert 'seasons' to integer (some values might be float due to NaNs)
merged_df["seasons"] = merged_df["seasons"].astype(int)

# Convert 'imdb_score', 'tmdb_score', 'imdb_votes', and 'tmdb_popularity' to float
merged_df["imdb_score"] = merged_df["imdb_score"].astype(float)
merged_df["tmdb_score"] = merged_df["tmdb_score"].astype(float)
merged_df["imdb_votes"] = merged_df["imdb_votes"].astype(float)
merged_df["tmdb_popularity"] = merged_df["tmdb_popularity"].astype(float)

print("\n Data Type Fixing Completed!")
print(merged_df.dtypes)
# Out:
#  Data Type Fixing Completed!
# person_id                 int64
# id                       object
# name                     object
# character                object
# role                     object
# title                    object
# type                     object
# description              object
# release_year              int32
# age_certification        object
# runtime                   int32
# genres                   object
# production_countries     object
# seasons                   int32
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
#Normalize categorical data
# Convert 'type' column to uppercase (MOVIE/SHOW)
merged_df["type"] = merged_df["type"].str.upper()

# Convert 'role' column to lowercase
merged_df["role"] = merged_df["role"].str.lower()

# Strip spaces and standardize 'age_certification'
merged_df["age_certification"] = merged_df["age_certification"].str.strip().str.upper()

# Replace any inconsistent values in 'age_certification'
age_mapping = {
    "G": "G",
    "PG": "PG",
    "PG-13": "PG-13",
    "R": "R",
    "NC-17": "NC-17",
    "NOT RATED": "NOT RATED"
}
merged_df["age_certification"] = merged_df["age_certification"].map(age_mapping).fillna("UNKNOWN")

print("\nCategorical Data Normalization Completed!")
print(merged_df[["type", "role", "age_certification"]].head())
# Out:
# Categorical Data Normalization Completed!
#     type   role age_certification
# 0   SHOW  actor           UNKNOWN
# 1   SHOW  actor           UNKNOWN
# 2   SHOW  actor           UNKNOWN
# 3  MOVIE  actor         NOT RATED
# 4  MOVIE  actor         NOT RATED

# %%
# Save the cleaned dataset to a new CSV file
merged_df.to_csv("cleaned_amazon_prime_data.csv", index=False)

print("\n Cleaned dataset saved successfully as 'cleaned_amazon_prime_data.csv'!")
# Out:
#  Cleaned dataset saved successfully as 'cleaned_amazon_prime_data.csv'!

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
#  Data Manipulations and Insights from the Amazon Prime Dataset
# During the data wrangling process, we performed multiple data cleaning and transformation steps to make the dataset ready for analysis. Below is a summary of the manipulations done and the insights gained from the dataset.
#
#  **Data Manipulations Performed**\
# **1️. Merging Datasets**\
#   Combined credits.csv (cast & crew) and titles.csv (movie/show details) using the id column.
#
# **2️. Handling Missing Values**
# * Filled missing values in character, age_certification, imdb_score, tmdb_score, and seasons using appropriate values (e.g., "Unknown", "Not Rated", median scores, and 0).
#
# **3️. Removing Duplicate Rows**\
# * Checked and removed duplicate rows to avoid redundancy.
#
# **4️. Fixing Data Types**\
# * Converted string lists (genres, production countries) into Python lists.
# * Ensured numerical columns (release_year, runtime, seasons, imdb_score) had correct data types.
#
# **5️. Normalizing Categorical Data
# * Standardized type (MOVIE/SHOW), role (lowercase), and age_certification values for uniformity.
#
# 6️. Saving the Cleaned Data
# * Exported the final cleaned dataset (cleaned_amazon_prime_data.csv) for EDA and visualization.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Count the number of movies and TV shows
content_counts = merged_df["type"].value_counts().reset_index()
content_counts.columns = ["type", "count"]  # Rename columns

# Define bright colors
colors = ["deepskyblue", "orange"]

# Plot the bar chart
plt.figure(figsize=(7, 5))
sns.barplot(data=content_counts, x="type", y="count", hue="type", palette=colors, legend=False)

# Add labels and title
plt.xlabel("Content Type", fontsize=12, fontweight="bold")
plt.ylabel("Count", fontsize=12, fontweight="bold")
plt.title("Distribution of Movies vs. TV Shows on Amazon Prime", fontsize=14, fontweight="bold")

# Show values on bars
for i, value in enumerate(content_counts["count"]):
    plt.text(i, value + 200, str(value), ha="center", fontsize=12, fontweight="bold", color="black")

# Remove top and right spines for a cleaner look
sns.despine()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is useful to compare the count of Movies vs. TV Shows in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart helps in understanding the dominance of either movies or TV shows on Amazon Prime.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.  the gained insights help creating a positive business impact

# %% [markdown]
# #### Chart - 2

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Create a histogram of IMDb scores
sns.histplot(merged_df["imdb_score"], bins=20, kde=True, color="dodgerblue")

# Add labels and title
plt.xlabel("IMDb Rating", fontsize=12, fontweight="bold")
plt.ylabel("Count of Titles", fontsize=12, fontweight="bold")
plt.title("Distribution of IMDb Ratings for Amazon Prime Content", fontsize=14, fontweight="bold")

# Show grid for better readability
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is ideal because it effectively shows how IMDb ratings are distributed across all Amazon Prime titles.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Most IMDb ratings fall between 6.0 and 8.5, indicating that Amazon Prime content is generally well-received.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! The insights help Amazon curate better content and improve recommendations.

# %% [markdown]
# #### Chart - 3

# %%
from collections import Counter

# Flatten the list of genres (since genres are stored as lists)
all_genres = [genre for sublist in merged_df["genres"] for genre in sublist]

# Count the occurrences of each genre
genre_counts = Counter(all_genres).most_common(10)  # Top 10 genres

# Convert to a DataFrame
genre_df = pd.DataFrame(genre_counts, columns=["Genre", "Count"])

# Plot the bar chart (fixing the warning)
plt.figure(figsize=(13, 5))
sns.barplot(data=genre_df, x="Count", y="Genre", hue="Genre", palette="plasma", dodge=False, legend=False)

# Add labels and title
plt.xlabel("Number of Titles", fontsize=12, fontweight="bold")
plt.ylabel("Genre", fontsize=12, fontweight="bold")
plt.title("Top 10 Most Common Genres on Amazon Prime", fontsize=14, fontweight="bold")

# Show values on bars
for index, value in enumerate(genre_df["Count"]):
    plt.text(value + 5, index, str(value), va="center", fontsize=12, fontweight="bold")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is perfect for comparing categorical data like genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Drama, Comedy, and Action are the most common genres on Amazon Prime.
# Thriller and Documentary genres are also quite popular, indicating a diverse content library. Genres like Horror and Sci-Fi have fewer titles, suggesting less focus on niche categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Yes! These insights help Amazon understand viewer preferences and optimize content.
#  Actionable Strategies:
#
# If Drama & Comedy dominate, Amazon can create more exclusive originals in these genres.
# If Horror & Sci-Fi are underrepresented, investing in these could attract niche audiences.

# %% [markdown]
# #### Chart - 4

# %%
# Set figure size
plt.figure(figsize=(8, 6))

# Create scatter plot
sns.scatterplot(data=merged_df, x="imdb_score", y="tmdb_score", alpha=0.5, color="purple")

# Add labels and title
plt.xlabel("IMDb Rating", fontsize=12, fontweight="bold")
plt.ylabel("TMDb Rating", fontsize=12, fontweight="bold")
plt.title("Correlation Between IMDb and TMDb Ratings", fontsize=14, fontweight="bold")

# Show the plot
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A scatter plot is ideal for identifying correlation between two numerical variables (IMDb and TMDb ratings).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A strong positive correlation suggests that IMDb and TMDb ratings align closely.
# 📌 If there is a lot of spread, it means that ratings differ significantly between IMDb and TMDb users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Yes! Understanding rating correlations helps Amazon improve its recommendation system.

# %% [markdown]
# #### Chart - 5

# %%
# Count number of titles released per year
yearly_trend = merged_df["release_year"].value_counts().sort_index()

# Set figure size
plt.figure(figsize=(10, 5))

# Create line plot
sns.lineplot(x=yearly_trend.index, y=yearly_trend.values, marker="o", color="blue")

# Add labels and title
plt.xlabel("Release Year", fontsize=12, fontweight="bold")
plt.ylabel("Number of Titles", fontsize=12, fontweight="bold")
plt.title("Trend of Movies and TV Shows Production Over the Years", fontsize=14, fontweight="bold")

# Show the plot
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A line chart is best for visualizing changes over time, helping to identify content production trends.
# It shows growth patterns, peaks, and declines in Amazon Prime’s movie & TV show releases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of titles released per year has increased significantly over time, indicating Amazon Prime's growing content library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Yes! Understanding content production trends helps Amazon plan future content investments strategically.

# %% [markdown]
# #### Chart - 6

# %%
import matplotlib.pyplot as plt

# Filter only directors and count the number of times they appear
top_directors = merged_df[merged_df["role"] == "director"]["name"].value_counts().head(10)

# Define colors for better visualization
colors = ["deepskyblue", "orange", "limegreen", "red", "purple", "cyan", "magenta", "gold", "pink", "brown"]

# Set figure size
plt.figure(figsize=(8, 8))

# Create pie chart
plt.pie(top_directors, labels=top_directors.index, autopct="%1.1f%%", colors=colors, startangle=140, wedgeprops={"edgecolor": "black"})

# Add title
plt.title("Top 10 Most Frequently Credited Directors on Amazon Prime", fontsize=14, fontweight="bold")

# Show the plot
plt.show()

# %% [markdown]
# #### Chart - 7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count top 10 most frequently credited actors
top_actors = merged_df[merged_df["role"] == "actor"]["name"].value_counts().head(10)

# Convert to DataFrame
top_actors_df = top_actors.reset_index()
top_actors_df.columns = ["Actor", "Count"]

# Set figure size
plt.figure(figsize=(10, 6))

# Create a bar chart with hue to avoid warning
sns.barplot(data=top_actors_df, x="Count", y="Actor", hue="Actor", palette="coolwarm", legend=False)

# Add labels and title
plt.xlabel("Number of Appearances", fontsize=12, fontweight="bold")
plt.ylabel("Actor Name", fontsize=12, fontweight="bold")
plt.title("Top 10 Most Frequently Credited Actors on Amazon Prime", fontsize=14, fontweight="bold")

# Show values on bars
for index, value in enumerate(top_actors_df["Count"]):
    plt.text(value + 2, index, str(value), fontsize=12, fontweight="bold")

# Show the plot
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is best for ranking actors by frequency. Horizontal bars improve readability when displaying names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some actors appear far more frequently than others, meaning they dominate Amazon Prime content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps Amazon strategically cast popular actors for high-engagement content.
# Useful for marketing campaigns (e.g., "Featuring [Top Actor] in multiple Prime Originals!").

# %% [markdown]
# #### Chart - 8

# %%
# Count the number of Movies and TV Shows
content_counts = merged_df["type"].value_counts()

# Define colors for better contrast
colors = ["deepskyblue", "orange"]

# Set figure size
plt.figure(figsize=(8, 8))

# Create a pie chart with a center circle (Donut Chart)
plt.pie(content_counts, labels=content_counts.index, autopct="%1.1f%%", colors=colors, startangle=140, wedgeprops={"edgecolor": "black"})
plt.gca().add_artist(plt.Circle((0, 0), 0.5, color="white"))  # Create the donut hole

# Add title
plt.title("Distribution of Movies vs. TV Shows on Amazon Prime", fontsize=14, fontweight="bold")

# Show the plot
plt.show()

# %% [markdown]
# #### Chart - 9

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define IMDb rating categories
bins = [0, 5, 6, 7, 8, 10]  # Ranges: 0-5, 5-6, 6-7, 7-8, 8-10
labels = ["Below 5", "5-6", "6-7", "7-8", "8+"]
merged_df["rating_category"] = pd.cut(merged_df["imdb_score"], bins=bins, labels=labels, include_lowest=True)

# Count the number of titles in each rating category
rating_distribution = merged_df["rating_category"].value_counts().sort_index()

# Convert to DataFrame
rating_df = rating_distribution.reset_index()
rating_df.columns = ["IMDb Rating Category", "Count"]

# Define bright colors
bright_colors = ["#FF5733", "#FFC300", "#33FF57", "#337BFF", "#9D33FF"]

# Set figure size
plt.figure(figsize=(8, 6))

# Create a bar chart with bright colors
sns.barplot(data=rating_df, x="IMDb Rating Category", y="Count", hue="IMDb Rating Category", palette=bright_colors, legend=False)

# Add labels and title
plt.xlabel("IMDb Rating Category", fontsize=12, fontweight="bold")
plt.ylabel("Number of Titles", fontsize=12, fontweight="bold")
plt.title("Distribution of IMDb Ratings on Amazon Prime", fontsize=14, fontweight="bold")

# Show values on bars
for index, value in enumerate(rating_df["Count"]):
    plt.text(index, value + 10, str(value), ha="center", fontsize=12, fontweight="bold")

# Show the plot
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Calculate the average IMDb rating for Movies and TV Shows
content_type_ratings = merged_df.groupby("type")["imdb_score"].mean()

# Define bright colors
colors = ["green", "purple"]

# Set figure size
plt.figure(figsize=(8, 8))

# Create a pie chart
plt.pie(content_type_ratings, labels=content_type_ratings.index, autopct="%1.1f%%", colors=colors, startangle=140, wedgeprops={"edgecolor": "black"})

# Add title
plt.title("Average IMDb Ratings: Movies vs. TV Shows on Amazon Prime", fontsize=14, fontweight="bold")

# Show the plot
plt.show()

# %% [markdown]
# #### Chart - 11

# %%
from collections import Counter

# Flatten the list of production countries (since production_countries is a list)
all_countries = [country for sublist in merged_df["production_countries"] for country in sublist]

# Count the occurrences of each country
country_counts = Counter(all_countries).most_common(10)  # Top 10 countries

# Convert to DataFrame
country_df = pd.DataFrame(country_counts, columns=["Country", "Count"])

# Set figure size
plt.figure(figsize=(10, 6))

# Create a histogram
sns.histplot(data=country_df, x="Country", weights="Count", bins=10, kde=False, color="red")

# Add labels and title
plt.xlabel("Country", fontsize=12, fontweight="bold")
plt.ylabel("Number of Titles Produced", fontsize=12, fontweight="bold")
plt.title("Top 10 Content-Producing Countries on Amazon Prime", fontsize=14, fontweight="bold")

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha="right", fontsize=10)

# Show the plot
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# #### Chart - 12

# %%
# Select only numerical columns for correlation
numeric_cols = merged_df.select_dtypes(include=["float64", "int64"])

# Compute the correlation matrix
correlation_matrix = numeric_cols.corr()

# Set figure size
plt.figure(figsize=(10, 6))

# Create heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Add title
plt.title("Correlation Heatmap of Amazon Prime Content Features", fontsize=14, fontweight="bold")

# Show the plot
plt.show()

# %% [markdown]
# #### Chart - 13 - Pair plot

# %%
# Select numerical columns for pair plot
numeric_cols = merged_df[["imdb_score", "tmdb_score", "runtime", "imdb_votes", "tmdb_popularity"]]

# Create pair plot
sns.pairplot(numeric_cols, diag_kind="kde", corner=True, plot_kws={"alpha": 0.5})

# Show the plot
plt.show()

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Optimize Content Strategy Based on Ratings & Popularity
# 📌 Insight: The correlation heatmap & IMDb rating analysis show that certain content types, genres, and runtimes perform better than others.
#
# ✅ Recommendation:
#
# Focus on highly-rated genres (e.g., Drama, Thriller, Action) for original content investments.\
# Improve low-rated genres by enhancing storytelling, production, and casting.\
# Use IMDb & TMDb scores to prioritize high-quality content recommendations.\
# 📈 Business Impact: Increases user engagement and watch time, leading to higher retention rates.
#
# 🔹 2️⃣ Expand Content Library in Underserved Regions\
# 📌 Insight: The content production heatmap shows that USA, UK, and India dominate content production, while other regions have fewer titles.
#
# ✅ Recommendation:
#
# Expand international content in Latin America, Africa, and East Asia to attract diverse global audiences.\
# Partner with regional filmmakers and studios to increase localized content.\
# Promote regional hits with localized marketing campaigns.\
# 📈 Business Impact: Increases subscriber growth in new markets and makes Amazon Prime more competitive globally.
#
# 🔹 3️⃣ Improve Recommendation System Using User Ratings & Watch Trends
# 📌 Insight: The pair plot & IMDb rating distribution show user preferences for certain types of content.
#
# ✅ Recommendation:
#
# Leverage machine learning to personalize recommendations based on watch history, ratings, and user engagement.\
# Promote highly-rated & trending content to maximize watch time.\
# Create personalized playlists (e.g., "Top 10 Must-Watch Thrillers" based on IMDb data).\
# 📈 Business Impact: Improves user satisfaction & retention, reducing churn rates.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# By implementing these data-driven recommendations, Amazon Prime can:
# * Optimize content investments based on ratings & trends.
# * Expand global reach with better regional content.
# * Enhance user engagement through smart recommendations.
# * Improve competitive positioning against Netflix & Disney+.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
